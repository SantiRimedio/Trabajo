# %%
import pandas as pd
import geopandas as gpd

gdf = gpd.read_file(r"S:\02-Actualizacion de bases\Bases DDEyPU\Obras Públicas y Privadas\Obras GCBA DGFYCO\Unión_Obras_Iniciadas_2017_2021\Union_Obras_Iniciadas_2017_2021.shp")
#gdf[["DIRECCION_","TIPO_OBRA_","SUPERF_","BARRIO_","COMUNA_","ZONA_","geometry"]]
gdf.columns = gdf.columns.str.replace('_', '')
gdf = gdf.drop(columns="OBJECTID")
gdf[["DIRECCION","SMP","EXPDGROC","FECHAINI","TIPOOBRA","DESTINO","SUPERF","BARRIO","COMUNA","ZONA","geometry"]]
gdf
# Out:
#       OBJECTID                DIRECCION           SMP  \
# 0            1             CHARLONE 790   037-006-010
# 1            2  NEWBERY, JORGE AV. 3961   033-018-041
# 2            3             CHARLONE  75   033-060-028
# 3            4              PALPA  3828   037-003-008
# 4            5            CHARLONE  979   037-013-012
# ...        ...                      ...           ...
# 5645      5646                      NaN   093-107-025
# 5646      5647                      NaN  010-070-001Y
# 5647      5648                      NaN   008-062-016
# 5648      5649                      NaN  010-065-014E
# 5649      5650                      NaN   010-084-012
#
#                               EXPDGROC    FECHAINI  COMISARIA  \
# 0                        29637597/2015         NaN          0
# 1                      16.577.659/2017         NaN          0
# 2                        27215071/2016         NaN          0
# 3                        14843404/2016         NaN          0
# ...

# %%
gdf1 = gpd.read_file(r"S:\02-Actualizacion de bases\Bases DDEyPU\Obras Públicas y Privadas\Obras GCBA DGFYCO\2022\TRIMESTRES\PRIMER TRIMESTRE 2022\Inicios_Obras_1erTrimestre_2022_2.shp")
gdf1.columns = gdf1.columns.str.replace('_', '')
gdf1 = gdf1[["CALLE","SMP","EXPDGROC","FECHADEI","TIPOOBRA","DESTINO","MTSACONS","BARRIOS","COMUNA1","ZONA","geometry"]]
gdf1
# Out:
#      FID1  FID11  FID111  FID111                      CALLE            SMP  \
# 0      30      2       2     198         RIO DE JANEIRO 229   017-003-022A
# 1      31      3       3     217         GUARDIA VIEJA 3764    013-008-009
# 2      32      4       4     236       GOMEZ, VALENTIN 3541    013-028-017
# 3      33      5       5     250             SARMIENTO 4088    017-079-008
# 4      34      6       6     263  SANCHEZ DE BUSTAMANTE 689    013-041-011
# ..    ...    ...     ...     ...                        ...            ...
# 326   281     87      87     291              ACASSUSO 5916   060-008-014B
# 327   282     88      88     302                    POLA 63    060-029-033
# 328   283    208     208     201    RUIZ DE LOS LLANOS 1420    093-108-035
# 329   284    209     209     223    RUIZ DE LOS LLANOS 1528    093-109-002
# 330   330     26      26     193              OLAVARRIA 396  006-034A-004C
#
#      COMISARIA                         MOTIVO  MTSACONS  \
# ...

# %%
gdf2 = gpd.read_file(r"S:\02-Actualizacion de bases\Bases DDEyPU\Obras Públicas y Privadas\Obras GCBA DGFYCO\2022\TRIMESTRES\SEGUNDO TRIMESTRE 2022\Iniciadas_2Trimestre_2022_2.shp")
gdf2.columns = gdf2.columns.str.replace('_', '')
gdf2 = gdf2[["DIRECCION","SMP","EXPDGROC","FECHAINIC","TIPOOBRA"]]
gdf2
# Out:
#      FID1  FID11  FID111  OBJECTID               DIRECCION           SMP  \
# 0      23      1      23         1              276 RAWSON  017-041-040D
# 1      24      2      24         2           4105 BELGRANO   036-045-027
# 2      25      3      25       221           COLOMBRES 219   036-118-042
# 3      53     54      53         3                985 LIMA   014-057-033
# 4      54    129      54         4           830 PICHINCHA   022-037-012
# ..    ...    ...     ...       ...                     ...           ...
# 226   201    135     201        53    GAMBOA, MARCELO 6139   093-104-029
# 227   202    136     202        57            ALCARAZ 6239  091-012A-033
# 228   203    137     203        58             NOGOYA 5910  093-079-001B
# 229   204    138     204       223  RUIZ DE LOS LLANOS 920   091-032-022
# 230   230    230     230       153     CASTANARES AV. 5442  066-010-004C
#
#      COMISARIA  COMUNA                         MOTIVO  MTSACONS  ... COMUNA2  \
# ...

# %%
gdf3 = gpd.read_file(r"S:\02-Actualizacion de bases\Bases DDEyPU\Obras Públicas y Privadas\Obras GCBA DGFYCO\2022\TRIMESTRES\TERCER TRIMESTRE 2022\Iniciadas_3Trimestre_2022_2.shp")
gdf3.columns = gdf3.columns.str.replace('_', '')
gdf3
# Out:
#      FID1  FID11  FID111 Status  Score Matchtype    Matchaddr              X  \
# 0      38      5      50      M  100.0         A  017-062-019  103516.744537
# 1      39      6      67      M  100.0         A  013-043-022  104550.392309
# 2      40      7      78      M  100.0         A  017-094-004  104001.859888
# 3      41      8     111    NaN    0.0       NaN          NaN       0.000000
# 4      42      9     115    NaN    0.0       NaN          NaN       0.000000
# ..    ...    ...     ...    ...    ...       ...          ...            ...
# 374   321     83     226    NaN    0.0       NaN          NaN       0.000000
# 375   322     84     345    NaN    0.0       NaN          NaN       0.000000
# 376   323    215     101      M  100.0         A  093-053-031   94313.421072
# 377   324    216     168    NaN    0.0       NaN          NaN       0.000000
# 378   325    217     310    NaN    0.0       NaN          NaN       0.000000
#
# ...

# %%
gdf4 = gpd.read_file(r"S:\02-Actualizacion de bases\Bases DDEyPU\Obras Públicas y Privadas\Obras GCBA DGFYCO\2022\TRIMESTRES\CUARTO TRIMESTRE 2022\Iniciadas_4Trimestre_2022.shp")
gdf4
# Out:
#                      DIRECCION           SMP  COMISARIA  \
# 0                  AGRELO 3534  028-020-005A          8
# 1       SALGUERO, JERONIMO 316   017-089-028          0
# 2      ESTADO DE PALESTINA 528  017-045-028E         11
# 3                  AGRELO 4066   036-058-007         10
# 4                  LAMBARE 847   017-008-016         11
# ..                         ...           ...        ...
# 270             ALPATACAL 6646  072-100B-009         42
# 271    JUSTO, JUAN B. AV. 9270   093-060-006         44
# 272                   ROMA 671   093-104-013         44
# 273  CERRI, DANIEL, Gral. 1131   010-068-025         30
# 274        LIBERTI, TOMAS 1180   008-061-007          0
#
#                             MOTIVO  MTS_A_CONS  FECHA_INIC  \
# 0                              NaN     1605.81  2022-10-14
# 1                              NaN       78.00  2022-10-11
# 2                              NaN     1360.00  2022-10-21
# ...
