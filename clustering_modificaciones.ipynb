# %%
import matplotlib.pyplot as plt
from shapely.ops import unary_union
import geopandas as gpd
import pandas as pd
import numpy as np
from sklearn.cluster import DBSCAN
from sklearn.metrics.pairwise import haversine_distances

# %%
df = pd.read_excel(r"C:\Users\nunez\OneDrive\Escritorio\Bases\base_2012_2022_limpia.xlsx")
#MacOS
#df = pd.read_excel("/Users/santi/Desktop/Work/Bases/base_2012_2022_limpia.xlsx")

#Select 2022
df = df[df["ANIO"] == 2022]

#Geojson barrios caba
GeoJson_barrios = "https://cdn.buenosaires.gob.ar/datosabiertos/datasets/ministerio-de-educacion/barrios/barrios.geojson"
geojson = gpd.read_file(GeoJson_barrios)

#Point geometries from lat, long columns
gdf = gpd.GeoDataFrame(df, geometry=gpd.points_from_xy( df["Longitud"], df["Latitud"]))

#Boundary of CABA
boundary = unary_union(geojson["geometry"]).exterior

#Removing al points outside of the boundary

# perform spatial join
joined = gpd.sjoin(gdf, geojson, op='within')

# filter out points that do not intersect with the boundary
points_within_boundary = joined[joined.index_right.notnull()]
clean_df = points_within_boundary
clean_df
# Out:
# C:\Users\nunez\PycharmProjects\Permisos_de_obra\venv\lib\site-packages\IPython\core\interactiveshell.py:3445: FutureWarning: The `op` parameter is deprecated and will be removed in a future release. Please use the `predicate` parameter instead.
#   if await self.run_code(code, result, async_=asy):
# C:\Users\nunez\AppData\Local\Temp\ipykernel_9896\793475506.py:21: UserWarning: CRS mismatch between the CRS of left geometries and the CRS of right geometries.
# Use `to_crs()` to reproject one of the input geometries to match the CRS of the other.
#
# Left CRS: None
# Right CRS: EPSG:4326
#
#   joined = gpd.sjoin(gdf, geojson, op='within')
#       Unnamed: 0.2  Unnamed: 0.1  Unnamed: 0  ANIO MES  TRIMESTRE  \
# 0                0           0.0           7  2022   1        1.0
# 2                2           2.0           9  2022   3        1.0
# 4                4           4.0          11  2022   3        1.0
# 5                5           5.0          12  2022   3        1.0
# 6                6           6.0          13  2022   2        1.0
# ...            ...           ...         ...   ...  ..        ...
# 2635          2635        2635.0        2329  2022   8        3.0
# 2636          2636        2636.0        2329  2022   8        3.0
# 2637          2637        2637.0        2330  2022   8        3.0
# 2638          2638        2638.0        2330  2022   8        3.0
# 3233          3233        3233.0        2821  2022  12        4.0
#
#                     FECHA                        DIRECCION TIPO_OBRA  \
# 0              3 ene 2022               GUARDIA VIEJA 3764         1
# 2              3 mar 2022                       RAWSON 276         1
# 4              2 mar 2022                      LAMBARE 847         1
# 5              4 mar 2022                   HUMAHUACA 3787         1
# 6              1 feb 2022                   SARMIENTO 4088         1
# ...                   ...                              ...       ...
# 2635  2022-08-24 00:00:00  AV. REGIMIENTO DE PATRICIOS 892         3
# 2636  2022-08-24 00:00:00  AV. REGIMIENTO DE PATRICIOS 892         3
# 2637  2022-08-30 00:00:00   AV. REGIMIENTO DE PATRICIOS 30         3
# 2638  2022-08-30 00:00:00   AV. REGIMIENTO DE PATRICIOS 30         3
# 3233  2022-12-23 00:00:00                 AV. CORDOBA 3113         1
#
#      TIPO_OBRA_CUR  ...                                                add  \
# 0       OBRA MAYOR  ...  GUARDIA VIEJA 3764 ALMAGRO Buenos Aires, Argen...
# 2       Obra Mayor  ...         RAWSON 276 ALMAGRO Buenos Aires, Argentina
# 4       OBRA MAYOR  ...        LAMBARE 847 ALMAGRO Buenos Aires, Argentina
# 5       OBRA MAYOR  ...     HUMAHUACA 3787 ALMAGRO Buenos Aires, Argentina
# 6       OBRA MAYOR  ...     SARMIENTO 4088 ALMAGRO Buenos Aires, Argentina
# ...            ...  ...                                                ...
# 2635    Obra Menor  ...  AV. REGIMIENTO DE PATRICIOS 892 BOCA Buenos Ai...
# 2636    Obra Menor  ...  AV. REGIMIENTO DE PATRICIOS 892 BOCA Buenos Ai...
# 2637    Obra Media  ...  AV. REGIMIENTO DE PATRICIOS 30 BOCA Buenos Air...
# 2638    Obra Media  ...  AV. REGIMIENTO DE PATRICIOS 30 BOCA Buenos Air...
# 3233    Obra Media  ...  AV. CORDOBA 3113 RECOLETA Buenos Aires, Argentina
#
#      location                                            address  \
# 0         0.0  GUARDIA VIEJA 3764 ALMAGRO Buenos Aires, Argen...
# 2         2.0         RAWSON 276 ALMAGRO Buenos Aires, Argentina
# 4         4.0        LAMBARE 847 ALMAGRO Buenos Aires, Argentina
# 5         5.0     HUMAHUACA 3787 ALMAGRO Buenos Aires, Argentina
# 6         6.0     SARMIENTO 4088 ALMAGRO Buenos Aires, Argentina
# ...       ...                                                ...
# 2635   2635.0  AV. REGIMIENTO DE PATRICIOS 892 BOCA Buenos Ai...
# 2636   2636.0  AV. REGIMIENTO DE PATRICIOS 892 BOCA Buenos Ai...
# 2637   2637.0  AV. REGIMIENTO DE PATRICIOS 30 BOCA Buenos Air...
# 2638   2638.0  AV. REGIMIENTO DE PATRICIOS 30 BOCA Buenos Air...
# 3233   3233.0  AV. CORDOBA 3113 RECOLETA Buenos Aires, Argentina
#
#                          geometry index_right       BARRIO COMUNA_right  \
# 0     POINT (-58.41723 -34.60122)           4      ALMAGRO          5.0
# 2     POINT (-58.42628 -34.60916)           4      ALMAGRO          5.0
# 4     POINT (-58.43047 -34.60510)           4      ALMAGRO          5.0
# 5     POINT (-58.41762 -34.60217)           4      ALMAGRO          5.0
# 6     POINT (-58.42254 -34.60481)           4      ALMAGRO          5.0
# ...                           ...         ...          ...          ...
# 2635  POINT (-58.36944 -34.63814)          47         BOCA          4.0
# 2636  POINT (-58.36944 -34.63814)          47         BOCA          4.0
# 2637  POINT (-58.37045 -34.62994)          47         BOCA          4.0
# 2638  POINT (-58.37045 -34.62994)          47         BOCA          4.0
# 3233  POINT (-58.38685 -34.59932)          42  SAN NICOLAS          1.0
#
#          PERIMETRO          AREA  OBJETO
# 0      8537.901368  4.050752e+06  BARRIO
# 2      8537.901368  4.050752e+06  BARRIO
# 4      8537.901368  4.050752e+06  BARRIO
# 5      8537.901368  4.050752e+06  BARRIO
# 6      8537.901368  4.050752e+06  BARRIO
# ...            ...           ...     ...
# 2635  20060.003939  5.036240e+06  BARRIO
# 2636  20060.003939  5.036240e+06  BARRIO
# 2637  20060.003939  5.036240e+06  BARRIO
# 2638  20060.003939  5.036240e+06  BARRIO
# 3233   6548.084754  2.289008e+06  BARRIO
#
# [3253 rows x 39 columns]

# %%
fig, ax = plt.subplots()
geojson["geometry"].plot(ax=ax, color='lightgrey')
points_within_boundary.plot(ax=ax, markersize=2)
plt.show()

# %%
clean_df = clean_df[clean_df["TIPO_OBRA"] == 3]
#clean_df = clean_df[clean_df["USO_1"] == "LOCAL COMERCIAL"]
clean_df.drop_duplicates(subset="geometry", keep='first', inplace=True, ignore_index=False)

points_in_radians = clean_df[['Latitud','Longitud']].apply(np.radians).values

distances = haversine_distances(points_in_radians) * 6371
# Out:
# C:\Users\nunez\AppData\Local\Temp\ipykernel_9896\4149398015.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   clean_df.drop_duplicates(subset="geometry", keep='first', inplace=True, ignore_index=False)

# %%
fig, ax = plt.subplots()
geojson["geometry"].plot(ax=ax, color='lightgrey')
clean_df.plot(ax=ax, markersize=2)
plt.show()

# %%
dbscan = DBSCAN(eps=0.2, min_samples=5, metric='precomputed')
labels = dbscan.fit_predict(distances)

# Add the cluster labels to the dataframe
clean_df['cluster'] = labels

distances
# Out:
# C:\Users\nunez\PycharmProjects\Permisos_de_obra\venv\lib\site-packages\geopandas\geodataframe.py:1443: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   super().__setitem__(key, value)
# array([[0.        , 1.55142196, 1.32971337, ..., 5.83837723, 5.62239963,
#         5.19429846],
#        [1.55142196, 0.        , 0.49216343, ..., 7.18700256, 6.9435304 ,
#         6.39925229],
#        [1.32971337, 0.49216343, 0.        , ..., 6.75795161, 6.50753687,
#         5.94021598],
#        ...,
#        [5.83837723, 7.18700256, 6.75795161, ..., 0.        , 0.31933137,
#         1.23362756],
#        [5.62239963, 6.9435304 , 6.50753687, ..., 0.31933137, 0.        ,
#         0.91743751],
#        [5.19429846, 6.39925229, 5.94021598, ..., 1.23362756, 0.91743751,
#         0.        ]])

# %%
fig, ax = plt.subplots()
geojson["geometry"].plot(ax=ax, color='lightgrey')
clean_df[clean_df["cluster"] != -1].plot(column="cluster", ax=ax, markersize=20, legend=True, cmap='tab20b')
# Out:
# <Axes: >

# %%
df_clusters = clean_df[clean_df["cluster"] != -1]

# %%
df_clusters = df_clusters[['Latitud','Longitud','cluster','SUP_CONST','USO_1']].reset_index(drop=True)
df_clusters['TIPO_OBRA'] = '3'

# %%
import folium
m = folium.Map(location=[-34.6, -58.4])
list = ['red', 'darkred', 'green', 'purple', 'white', 'cadetblue', 'darkpurple', 'pink', 'darkgreen', 'gray', 'lightgray', 'blue', 'lightred', 'lightgreen', 'beige', 'black', 'lightblue', 'orange', "darkblue"]

for index, row in df_clusters.iterrows():
    folium.Marker(location=[row["Latitud"], row["Longitud"]],popup=f"Cluster {row['USO_1']}" ,icon=folium.Icon(color=list[row["cluster"]])).add_to(m)

# %%
df_clusters_on = pd.read_csv('clusters_obras nuevas.csv')
df_clusters_on
# Out:
#      Unnamed: 0    Latitud   Longitud  cluster  SUP_CONST  \
# 0             0 -34.571426 -58.449471        0    2085.73
# 1             1 -34.571815 -58.447047        0    1563.71
# 2             2 -34.571910 -58.448831        0   16837.48
# 3             3 -34.570910 -58.449229        0    1421.67
# 4             4 -34.570976 -58.447143        0    1736.39
# ..          ...        ...        ...      ...        ...
# 121         121 -34.641742 -58.508416       15    1572.23
# 122         122 -34.559586 -58.470672        3    2449.53
# 123         123 -34.557394 -58.470673        3     760.83
# 124         124 -34.564471 -58.472283        5     818.61
# 125         125 -34.558234 -58.470384        3    1077.34
#
#                       USO_1  TIPO_OBRA
# 0    VIVIENDA MULTIFAMILIAR          1
# 1    VIVIENDA MULTIFAMILIAR          1
# 2    VIVIENDA MULTIFAMILIAR          1
# 3    VIVIENDA MULTIFAMILIAR          1
# 4    VIVIENDA MULTIFAMILIAR          1
# ..                      ...        ...
# 121  VIVIENDA MULTIFAMILIAR          1
# 122               SIN DATOS          1
# 123               SIN DATOS          1
# 124               SIN DATOS          1
# 125  VIVIENDA MULTIFAMILIAR          1
#
# [126 rows x 7 columns]

# %%
df_clusters
# Out:
#       Latitud   Longitud  cluster SUP_CONST                   USO_1 TIPO_OBRA
# 0  -34.594013 -58.429449        0     52.54               SIN DATOS         3
# 1  -34.591862 -58.428928        0    222.91  VIVIENDA MULTIFAMILIAR         3
# 2  -34.592704 -58.428615        0         0    VIVIENDA UNIFAMILIAR         3
# 3  -34.593895 -58.429273        0         0               SIN DATOS         3
# 4  -34.587936 -58.439070        3         0  VIVIENDA MULTIFAMILIAR         3
# ..        ...        ...      ...       ...                     ...       ...
# 58 -34.638057 -58.499464       11         0  VIVIENDA MULTIFAMILIAR         3
# 59 -34.639847 -58.502076       11    301.17  VIVIENDA MULTIFAMILIAR         3
# 60 -34.639546 -58.500476       11   5943.89  VIVIENDA MULTIFAMILIAR         3
# 61 -34.638589 -58.500838       11   1619.09  VIVIENDA MULTIFAMILIAR         3
# 62 -34.562180 -58.480521        7    128.29    VIVIENDA UNIFAMILIAR         3
#
# [63 rows x 6 columns]

# %%
pd.concat([df_clusters_on,df_clusters]).to_excel(r'C:\Users\nunez\OneDrive\Escritorio\Bases\clusters\clusters.xlsx')
